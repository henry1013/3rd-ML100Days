# %%
import pandas as pd
import numpy as np
data = {'class': ['101', '102', '103', '104'],
        'boy': ['16', '15', '13', '19'],
        'girl': [13, 14, 17, 15]}
class_1 = pd.DataFrame(data)
print(class_1)
# Out:
#   class boy  girl
# 0   101  16    13
# 1   102  15    14
# 2   103  13    17
# 3   104  19    15
